# %%
#load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
col_names = ['A', 'B', 'C', 'Play']
#load dataset
dataset = pd.read_csv("assignment2_1.csv", header=None, names=col_names)

# %%
dataset.head()
# Out:
#    A  B  C Play
# 0  1  1  1    Y
# 1  1  1  0    N
# 2  1  0  1    Y
# 3  1  0  0    N
# 4  0  1  1    Y

# %%
#split dataset in features and target variable
feature_cols = ['A', 'B', 'C']
X = dataset[feature_cols]
y = dataset.Play

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)
#75% training and 25% test

# %%
#create decision tree classifier object
clf = DecisionTreeClassifier()

#Train Decision Tree Classifier
clf = clf.fit(X_train, y_train)

#Predict the response
y_pred = clf.predict(X_test)

# %%
#model accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5

# %%
# !pip install pydotplus
# Out:
# Collecting pydotplus
#   Cache entry deserialization failed, entry ignored
#   Cache entry deserialization failed, entry ignored
#   Downloading https://files.pythonhosted.org/packages/60/bf/62567830b700d9f6930e9ab6831d6ba256f7b0b730acb37278b0ccdffacf/pydotplus-2.0.2.tar.gz (278kB)
#     100% |████████████████████████████████| 286kB 220kB/s ta 0:00:011
# Requirement already satisfied: pyparsing>=2.0.1 in /Users/jungheekang/anaconda3/envs/wikiml/lib/python3.6/site-packages (from pydotplus)
# Building wheels for collected packages: pydotplus
#   Running setup.py bdist_wheel for pydotplus ... done
#   Stored in directory: /Users/jungheekang/Library/Caches/pip/wheels/35/7b/ab/66fb7b2ac1f6df87475b09dc48e707b6e0de80a6d8444e3628
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2
# You are using pip version 9.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data, filled=True, rounded=True, special_characters=True, feature_names=feature_cols, class_names=['0', '1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('assignmnet.png')
Image(graph.create_png())
# Out:
# Warning: Could not load "/Users/jungheekang/anaconda3/envs/wikiml/lib/graphviz/libgvplugin_pango.6.dylib" - file not found
# Warning: Could not load "/Users/jungheekang/anaconda3/envs/wikiml/lib/graphviz/libgvplugin_pango.6.dylib" - file not found
# Warning: Could not load "/Users/jungheekang/anaconda3/envs/wikiml/lib/graphviz/libgvplugin_pango.6.dylib" - file not found
#
# Warning: Could not load "/Users/jungheekang/anaconda3/envs/wikiml/lib/graphviz/libgvplugin_pango.6.dylib" - file not found
# Warning: Could not load "/Users/jungheekang/anaconda3/envs/wikiml/lib/graphviz/libgvplugin_pango.6.dylib" - file not found
# Warning: Could not load "/Users/jungheekang/anaconda3/envs/wikiml/lib/graphviz/libgvplugin_pango.6.dylib" - file not found

# %%
#create decision tree classifier object
clf = DecisionTreeClassifier(criterion="entropy", max_depth=2)

#Train Decision Tree Classifier
clf = clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

#Model Accuracy, how often is the classifier correct?
print("Accuracy : ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.5
